# %% [markdown]
# # Copyright Netherlands eScience Center <br>
# ** Function     : AMET from coordinated EC-Earth experiment 2 ** <br>
# ** Author       : Yang Liu ** <br>
# ** First Built  : 2018.10.16 ** <br>
# ** Last Update  : 2018.10.16 ** <br>
# Description  : This script serves to check the AMET calculated from coordinated EC-Earth experiment 2. It includes 10 members in total. <br>
# Return Values : jpeg <br>
# Caveat! : The time series spans from 1979 to 2015 (37 years)

# %%
# %matplotlib inline

import sys
sys.path.append("/home/yang/NLeSC/Computation_Modeling/Bjerknes/Scripts/META")
import numpy as np
import scipy
from netCDF4 import Dataset
import matplotlib
import matplotlib.pyplot as plt
import os
import meta.statistics
import meta.visualizer
from scipy import stats

# %%
# constants
constant = {'g' : 9.80616,      # gravititional acceleration [m / s2]
            'R' : 6371009,      # radius of the earth [m]
            'cp': 1004.64,      # heat capacity of air [J/(Kg*K)]
            'Lv': 2264670,      # Latent heat of vaporization [J/Kg]
            'R_dry' : 286.9,    # gas constant of dry air [J/(kg*K)]
            'R_vap' : 461.5,    # gas constant for water vapour [J/(kg*K)]
            'HoF' : 334,        # heat of fusion of ice [KJ/Kg] 
            'rho_ice' : 0.91    # density of sea ice [g/cm3]
            }

# %%
if __name__=="__main__":
    # sample
    ################################   Input zone  ######################################
    # specify data path
    datapath = '/home/yang/workbench/Core_Database_AMET_OMET_reanalysis/EC-earth_coordExp/Exp2'
    output_path = '/home/yang/NLeSC/Computation_Modeling/Bjerknes/EC-Earth'
    #####################################################################################
    #####################################################################################
    print ('*********************** extract variables *************************')
    benchmark_dataset = Dataset(os.path.join(datapath, '4RXF', 'postprocessing',
                                'AMET_EC-earth_model_daily_4RXF_1979_2015_E_zonal_int.nc'))
    latitude = benchmark_dataset.variables['latitude'][:]
    year = benchmark_dataset.variables['year'][:]
    namelist_exp = ['4RXF', '5DEH', 'ITNV']
    #namelist_exp = ['ITNV']
    Dim_lat = 512
    Dim_lon = 1024
    AMET_zonal = {'4RXF' : np.zeros((len(year), 12, Dim_lat), dtype=float),
                  '5DEH' : np.zeros((len(year), 12, Dim_lat), dtype=float), 
                  'ITNV' : np.zeros((len(year), 12, Dim_lat), dtype=float),}
    for c in namelist_exp:
        dataset_ECE = Dataset(os.path.join(datapath, c, 'postprocessing',
                              'AMET_EC-earth_model_daily_{}_1979_2015_E_zonal_int.nc'.format(c)))
        AMET_ECE_zonal = dataset_ECE.variables['E'][:]/1000
        AMET_zonal['{}'.format(c)][:] = AMET_ECE_zonal[:]
# Out:
# *********************** extract variables *************************

# %%
    print (latitude[85])
    # make time series of the AMET from each member
# Out:
# 59.88288

# %%
    ##########################  mean AMET at different lat  ############################
    fig1 = plt.figure()
    fig1.set_size_inches(8, 6)
    plt.axhline(y=0, color='k',ls='-')
    for c in namelist_exp:
        AMET_mean = np.mean(np.mean(AMET_zonal['{}'.format(c)][:],0),0)
        plt.plot(latitude, AMET_mean, linewidth=1.5, label='exp {}'.format(c))
    plt.xlabel("latitude",fontsize=16)
    plt.ylabel("Meridional Energy Transport(PW)",fontsize=16)
    plt.yticks(fontsize=16)
    plt.legend(frameon=True, loc=1, prop={'size': 16})
    plt.show()
    fig1.savefig(os.path.join(output_path,'AMET_mean.png'),dpi=300)
    plt.close(fig1)

# %%
    ##########################  time series of AMET at 60N  ############################
    index_year = np.arange(1980,year[-1]+1,5)
    index = np.arange(1,len(year)*12+1,1) # 1979 - 2015
    
    fig2 = plt.figure()
    fig2.set_size_inches(12.5, 6) 
    for c in namelist_exp:
        AMET_60N = AMET_zonal['{}'.format(c)][:].reshape(len(year)*12,Dim_lat)
        plt.plot(index, AMET_60N[:,85], linewidth=1.5, label='exp {}'.format(c))
    plt.xlabel("Time",fontsize=16)
    plt.xticks(np.arange(1,len(year)*12+1,60), index_year,fontsize=16)
    plt.ylabel("Meridional Energy Transport(PW)",fontsize=16)
    plt.yticks(fontsize=16)
    plt.legend(frameon=True, loc=2, prop={'size': 16})
    plt.show()
    fig2.savefig(os.path.join(output_path,'AMET_60N.png'),dpi=300)
    plt.close(fig2)

# %%
    #######################  time series of AMET anomalies at 60N  #########################
    index_year = np.arange(1980,year[-1]+1,5)
    index = np.arange(1,len(year)*12+1,1) # 1979 - 2015
    
    fig3 = plt.figure()
    fig3.set_size_inches(12.5, 6) 
    for c in namelist_exp:
        AMET_matrix = AMET_zonal['{}'.format(c)][:]
        stat_AMET = meta.statistics.operator(AMET_matrix)
        stat_AMET.anomaly()
        #stat_AMET.lowpass(window=12)
        plt.plot(index[:], stat_AMET._anomaly[:,85], linewidth=1.5, label='exp {}'.format(c))
    plt.xlabel("Time",fontsize=16)
    plt.xticks(np.arange(1,len(year)*12+1,60), index_year,fontsize=16)
    plt.ylabel("Meridional Energy Transport(PW)",fontsize=16)
    plt.yticks(fontsize=16)
    plt.legend(frameon=True, loc=2, prop={'size': 16})
    plt.show()
    fig3.savefig(os.path.join(output_path,'AMET_anomaly_60N.png'),dpi=300)
    plt.close(fig3)
# Out:
# The input data has the dimension of month.
# The output anomaly time series only contains one dimension for time!
# The input data has the dimension of month.
# The output anomaly time series only contains one dimension for time!
# The input data has the dimension of month.
# The output anomaly time series only contains one dimension for time!

# %%
    #######################  time series of AMET anomalies at 60N  #########################
    index_year = np.arange(1980,year[-1]+1,5)
    index = np.arange(1,len(year)*12+1,1) # 1979 - 2015
    
    fig4 = plt.figure()
    fig4.set_size_inches(12.5, 6) 
    for c in namelist_exp:
        AMET_matrix = AMET_zonal['{}'.format(c)][:]
        stat_AMET = meta.statistics.operator(AMET_matrix)
        stat_AMET.anomaly()
        stat_AMET.lowpass(window=60)
        plt.plot(index[59:], stat_AMET._lowpass[:,85], linewidth=1.5, label='exp {}'.format(c))
    plt.xlabel("Time",fontsize=16)
    plt.xticks(np.arange(1,len(year)*12+1,60), index_year,fontsize=16)
    plt.ylabel("Meridional Energy Transport(PW)",fontsize=16)
    plt.yticks(fontsize=16)
    plt.legend(frameon=True, loc=2, prop={'size': 16})
    plt.show()
    fig4.savefig(os.path.join(output_path,'AMET_anomaly_60N_lowpass_5yr.png'),dpi=300)
    plt.close(fig4)
# Out:
# The input data has the dimension of month.
# The output anomaly time series only contains one dimension for time!
# The input data has the dimension of month.
# The output anomaly time series only contains one dimension for time!
# The input data has the dimension of month.
# The output anomaly time series only contains one dimension for time!

# %%
    print(AMET_zonal['ITNV'].reshape(len(year)*12,Dim_lat)[:,85])
# Out:
# [3.89846045 4.1467079  2.85988425 2.88533016 2.40807324 1.25045611
#  1.25499747 1.96765885 2.38692262 3.88383711 3.16004568 4.29106411
#  4.87210292 3.2269272  3.65448    2.6926989  1.98591297 1.06765739
#  1.49138549 1.63986077 2.7516913  3.36323282 3.29419717 3.34531316
#  4.07451136 4.00462452 3.18374542 2.69352935 2.07691845 1.5739976
#  1.38844294 1.87462992 2.84233591 2.95869995 3.65040891 3.43536788
#  4.06419983 3.52167664 3.50172733 2.61271596 1.9846339  1.45060801
#  1.73062583 1.94046991 2.37847049 3.03856687 3.33567854 3.42985635
#  4.37114883 3.76949973 3.04196976 3.25590851 2.2031365  1.27364419
#  1.15669236 2.03850208 2.32437866 3.43957687 3.55073421 3.68460704
#  4.3365696  3.8251066  2.91664822 2.70319322 2.08192466 1.16697875
#  1.35819233 1.62154744 2.52398641 3.88790688 3.18661399 2.78620164
#  3.95767319 4.40876369 3.24797693 3.06600568 1.92514043 1.17713993
#  1.43738257 1.59647752 2.6449043  3.01968928 3.30633643 3.50704426
#  3.45221528 4.26403124 3.57097651 2.35025298 2.29707827 1.31803941
#  1.53064538 1.63751588 2.92078041 3.24974322 3.22188696 3.29532337
#  3.86562377 3.48530744 3.53894191 3.19088752 1.95780296 1.40689709
#  1.12055835 2.04327203 2.57681908 2.97522285 3.3038715  3.74124378
#  3.69941692 4.06882844 3.77427238 2.56134751 1.93301603 1.3777282
#  1.31445153 1.92211122 2.84849549 3.07170025 2.74164159 3.58379559
#  3.77417907 4.61012604 3.39697701 2.28089583 2.3426582  1.54874265
#  1.05846367 1.85899093 2.66233311 3.25754799 3.57345131 3.51627676
#  3.85320956 3.62873809 3.55713782 2.60124095 1.8547368  1.35834547
#  1.26019868 1.88152007 2.43293494 3.02547807 3.80798186 3.85589609
#  4.64900836 3.22757917 3.66372188 2.70950472 2.3137174  1.51129599
#  1.28531276 1.69934213 2.33106454 3.94118052 2.55803181 4.24257404
#  4.18564314 3.6645631  3.46887851 2.67773931 1.99495292 1.39595003
#  1.48910092 1.9681953  2.29799956 3.44949894 3.48523956 3.6504094
#  4.88639264 3.43061852 3.75042797 2.37064018 2.3684928  1.28030864
#  1.60436821 1.81838134 2.66741416 3.11058897 2.93832395 3.51068255
#  3.56359923 5.06641006 3.07959866 2.6288124  1.9556653  1.3316099
#  1.56718641 1.76172848 3.00296879 3.41283735 3.45459968 3.31525377
#  4.70176704 3.20569744 2.99023794 2.9528393  2.06591789 1.36814623
#  1.52794128 1.87514434 2.35074978 3.36062283 3.37444778 4.40500401
#  3.85795462 4.33699179 3.132439   2.92254023 2.07182308 1.42874169
#  1.16389223 2.09893652 2.44806217 3.17931859 4.32114302 3.29289317
#  4.25247163 4.31582346 3.40930952 2.85824646 1.85398024 1.35588756
#  1.46825504 1.92688316 2.95722596 2.78182695 3.70854724 3.89751965
#  3.89629554 4.21133382 3.25710643 2.78945498 2.00430127 1.43597105
#  1.50738729 1.68342467 2.74177017 2.7508818  3.77690807 3.38649785
#  4.32512219 3.65144035 3.42010097 2.92988457 2.03091623 1.13179557
#  1.42885851 2.09105215 2.51835806 3.34587571 3.27428612 3.71481004
#  4.33963586 3.85644343 3.5961613  2.27047842 2.11286577 1.45919422
#  1.31052618 2.30352411 2.37699964 3.37344099 3.23800048 3.21208222
#  2.84618176 4.58976843 3.70321721 2.54786249 1.86854834 1.47089108
#  1.44551666 1.74406519 2.63096847 3.33489377 3.0433625  3.43963518
#  4.93963178 3.20031045 3.56016613 2.70397983 1.67996834 1.47640547
#  1.06403422 1.82416328 2.73776167 2.74625687 4.29926573 4.01248365
#  3.63496537 3.39441257 3.36963746 2.56197411 2.40949875 1.41597215
#  1.10933899 1.70457341 2.58580913 3.14259632 3.17932326 4.22562648
#  4.60135605 4.08504024 2.85411173 2.45215601 2.20161452 1.46832146
#  1.12784386 1.78547158 2.84468977 2.88890608 3.52693132 4.060532
#  3.74008609 3.98538727 3.33148767 3.0721388  1.84660751 1.32066327
#  1.26966413 1.89040944 2.61963857 3.32718133 3.86052449 3.36384437
#  3.36035612 3.43371416 3.33831237 3.22626806 1.97776537 1.41476664
#  1.1911943  2.19195271 2.55991501 2.93108364 3.84027496 3.17953209
#  4.78102616 4.16205025 2.45024361 3.48832988 1.59337266 1.65474701
#  1.37000097 1.7202025  2.41196459 3.66568523 3.10518496 3.31353098
#  3.46780861 3.86006194 3.73542427 2.35627192 1.95149894 1.60795325
#  1.40292898 1.8806482  2.75223528 2.41695644 3.65333187 4.17081176
#  4.23121233        nan 2.79416105 2.79416105 2.07221074 1.45882282
#  1.52013071 1.89236043 2.83688384 2.70435733 3.23193911 3.71275486
#  4.55862638 3.791439   3.22569831 2.86886224 1.96212817 1.34493945
#  1.42608982 1.70728363 2.56878936 3.23964397 3.41278997 3.90447236
#  3.67619468 3.71344646 3.7409946  2.40838148 2.17104796 1.14567458
#  1.26812795 1.78898795 2.6379302  3.31793735 4.00297813 3.21108244
#  3.5099039  3.58246621 3.62398124 2.96836341 2.16826751 1.51951917
#  1.16272028 1.72741719 2.35781215 3.48465132 3.55348087 3.21848707
#  3.6747818  4.76519832 2.75528354 2.38571083 2.15445862 1.58215743
#  1.28119217 1.84424559 2.7257387  3.19739237 3.66761414 3.43467026
#  4.2468788  3.74870136 4.05211121 2.42122657 2.15643975 1.3029397
#  1.25563489 2.15123536 2.65681121 2.76244797 4.14410257 3.18564686
#  3.8284655  5.01903709 3.52683055 2.74755966 2.17738556 1.34927719
#  1.3716456  1.53996665 2.39852671 3.43335608 3.48079826 3.34743116]
