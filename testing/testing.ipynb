# %%
import numpy as np
from netCDF4 import Dataset
import os
import matplotlib.pyplot as plt

# %%
datapath = '/home/ESLT0068/WorkFlow/Core_Database_BlueAction_WP3/ECEarth_NLeSC/exp1'
data_key = Dataset(os.path.join(datapath, "model_daily_E_eddies_point.nc"))
vT_transient_zonal = data_key.variables['cpT_transient_zonal'][:]
lat = data_key.variables['latitude'][:]

# %%
vT_mean = np.mean(np.mean(vT_transient_zonal,0),0)

plt.plot(lat, vT_mean)
#print(vT_mean)
