# %% [markdown]
# # Copyright Netherlands eScience Center <br>
# ** Function     : Packing netCDF for the radiation and turbulent flux fields (TOA & surface) from MERRA2** <br>
# ** Author       : Yang Liu ** <br>
# ** First Built  : 2018.10.03 ** <br>
# ** Last Update  : 2018.10.03 ** <br>
# Description     : This notebook aims to pack the TOA/surface fields of radiations from ERA-Interim.<br>
# Return Values   : netCDF4 <br>
# Caveat          : The radiations fields are forecast fields instead of analysis fields. Unlike ERA-Interim, those forecast fields are unpacked by NASA and thus they are not accumulated values. They can be used directly. However, attention should be paid on the sign.<br>
# In contrast to ERA-Interim, for the flux in MERRA2, the **positive sign** for each variable varies:<br>
# * Net shortwave radiation at surface - downward <br>
# * Net shortwave radiation at TOA - downward <br>
# * Net longwave radiation at surface - downward <br>
# * Upwelling longwave radiation at TOA - upward <br>
# * Total latent energy flux - upward <br>
# * Sensible heat flux - upward <br>

# %%
import numpy as np
from netCDF4 import Dataset
import os

# %% [markdown]
# Initialization - Start with location of input and extraction of variables
# Time span of each product:
# - **ERA-Interim** 1979 - 2016
# - **MERRA2**      1980 - 2016
# - **JRA55**       1979 - 2015
# - **ORAS4**       1958 - 2017
# - **GLORYS2V3**   1993 - 2014
# - **SODA3**       1980 - 2015

# %%
################################   Input zone  ######################################
# specify starting and ending time
start_year = 1980
end_year = 2017
# specify data path
# MERRA2 2D fields - radiations
datapath_Rad = '/home/yang/workbench/Core_Database_AMET_OMET_reanalysis/MERRA2/regression/MERRA2_tavgM_2d_rad_Nx'
# MERRA2 2D fields - turbulent flux
datapath_SFlux = '/home/yang/workbench/Core_Database_AMET_OMET_reanalysis/MERRA2/regression/MERRA2_tavgM_2d_sflx_Nx'
# specify output path for figures
output_path = '/home/yang/workbench/Core_Database_AMET_OMET_reanalysis/MERRA2/regression'
####################################################################################

# %%
def var_key_retrieve(datapath_Rad, datapath_SFlux, year, month):
    # get the path to each datasets
    print ("Start retrieving datasets {} (y) - {} (m)".format(year,namelist_month[month-1]))
    # The shape of each variable is (361,576)
    # Sea Level Pressure
    if year < 1992:
        datapath_Rad_full = os.path.join(datapath_Rad,
                                         'MERRA2_100.tavgM_2d_rad_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    elif year < 2001:
        datapath_Rad_full = os.path.join(datapath_Rad,
                                         'MERRA2_200.tavgM_2d_rad_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    elif year < 2011:
        datapath_Rad_full = os.path.join(datapath_Rad,
                                         'MERRA2_300.tavgM_2d_rad_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    else:
        datapath_Rad_full = os.path.join(datapath_Rad,
                                         'MERRA2_400.tavgM_2d_rad_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    # get the variable keys
    var_key_Rad = Dataset(datapath_Rad_full)

    #Sea Surface Temperature and Sea Ice Concentration
    if year < 1992:
        datapath_SFlux_full = os.path.join(datapath_SFlux,
                                           'MERRA2_100.tavgM_2d_flx_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    elif year < 2001:
        datapath_SFlux_full = os.path.join(datapath_SFlux,
                                           'MERRA2_200.tavgM_2d_flx_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    elif year < 2011:
        datapath_SFlux_full = os.path.join(datapath_SFlux,
                                           'MERRA2_300.tavgM_2d_flx_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    else:
        datapath_SFlux_full = os.path.join(datapath_SFlux,
                                           'MERRA2_400.tavgM_2d_flx_Nx.{}{}.SUB.nc4'.format(year,namelist_month[month-1]))
    # get the variable keys
    var_key_SFlux = Dataset(datapath_SFlux_full)

    print ("Retrieving datasets successfully and return the variable key!")
    return var_key_Rad, var_key_SFlux

# %%
def create_netcdf_point(pool_EFLUX,pool_HFLUX,pool_LWGNT,pool_LWTUP,
                          pool_SWGNT, pool_SWTNT, output_path):
    print ('*******************************************************************')
    print ('*********************** create netcdf file*************************')
    print ('*******************************************************************')
    # wrap the datasets into netcdf file
    # 'NETCDF3_CLASSIC', 'NETCDF3_64BIT', 'NETCDF4_CLASSIC', and 'NETCDF4'
    data_wrap = Dataset(os.path.join(output_path, 'surface_merra_monthly_regress_1980_2017_SFlux_Rad.nc'),'w',format = 'NETCDF4')
    # create dimensions for netcdf data
    year_wrap_dim = data_wrap.createDimension('year',Dim_year)
    month_wrap_dim = data_wrap.createDimension('month',Dim_month)
    lat_wrap_dim = data_wrap.createDimension('latitude',Dim_latitude)
    lon_wrap_dim = data_wrap.createDimension('longitude',Dim_longitude)
    # create coordinate variables for 3-dimensions
    year_wrap_var = data_wrap.createVariable('year',np.int32,('year',))
    month_wrap_var = data_wrap.createVariable('month',np.int32,('month',))
    lat_wrap_var = data_wrap.createVariable('latitude',np.float32,('latitude',))
    lon_wrap_var = data_wrap.createVariable('longitude',np.float32,('longitude',))
    # create the actual 3-d variable
    EFLUX_wrap_var = data_wrap.createVariable('EFLUX',np.float64,('year','month','latitude','longitude'),zlib=True)
    HFLUX_wrap_var = data_wrap.createVariable('HFLUX',np.float64,('year','month','latitude','longitude'),zlib=True)
    LWGNT_wrap_var = data_wrap.createVariable('LWGNT',np.float64,('year','month','latitude','longitude'),zlib=True)
    LWTUP_wrap_var = data_wrap.createVariable('LWTUP',np.float64,('year','month','latitude','longitude'),zlib=True)
    SWGNT_wrap_var = data_wrap.createVariable('SWGNT',np.float64,('year','month','latitude','longitude'),zlib=True)
    SWTNT_wrap_var = data_wrap.createVariable('SWTNT',np.float64,('year','month','latitude','longitude'),zlib=True)
    # global attributes
    data_wrap.description = 'Monthly mean 2D fields of radiation and turbulent flux from MERRA2 at each grid point'
    # variable attributes
    lat_wrap_var.units = 'degree_north'
    lon_wrap_var.units = 'degree_east'

    EFLUX_wrap_var.units = 'W/m2'
    HFLUX_wrap_var.units = 'W/m2'
    LWGNT_wrap_var.units = 'W/m2'
    LWTUP_wrap_var.units = 'W/m2'
    SWGNT_wrap_var.units = 'W/m2'
    SWTNT_wrap_var.units = 'W/m2'

    EFLUX_wrap_var.long_name = 'latent energy flux'
    HFLUX_wrap_var.long_name = 'sensible heat flux'
    LWGNT_wrap_var.long_name = 'surface net downward longwave flux'
    LWTUP_wrap_var.long_name = 'upwelling longwave flux at toa'
    SWGNT_wrap_var.long_name = 'surface net downward shortwave flux'
    SWTNT_wrap_var.long_name = 'toa net downward_shortwave flux'

    # writing data
    lat_wrap_var[:] = latitude
    lon_wrap_var[:] = longitude
    month_wrap_var[:] = index_month
    year_wrap_var[:] = period

    EFLUX_wrap_var[:] = pool_EFLUX
    HFLUX_wrap_var[:] = pool_HFLUX
    LWGNT_wrap_var[:] = pool_LWGNT
    LWTUP_wrap_var[:] = pool_LWTUP
    SWGNT_wrap_var[:] = pool_SWGNT
    SWTNT_wrap_var[:] = pool_SWTNT

    # close the file
    data_wrap.close()
    print ("Create netcdf file successfully")

# %%
if __name__=="__main__":
    ####################################################################
    ######  Create time namelist matrix for variable extraction  #######
    ####################################################################
    # date and time arrangement
    # namelist of month and days for file manipulation
    namelist_month = ['01','02','03','04','05','06','07','08','09','10','11','12']
    # index of months
    period = np.arange(start_year,end_year+1,1)
    index_month = np.arange(1,13,1)
    ####################################################################
    ######       Extract invariant and calculate constants       #######
    ####################################################################
    # get invariant from benchmark file
    Dim_year = len(period)
    Dim_month = len(index_month)
    Dim_latitude = 361
    Dim_longitude = 576
    #############################################
    #####   Create space for stroing data   #####
    #############################################
    # data pool for zonal integral
    pool_EFLUX = np.zeros((Dim_year,Dim_month,Dim_latitude,Dim_longitude),dtype = float)
    pool_HFLUX = np.zeros((Dim_year,Dim_month,Dim_latitude,Dim_longitude),dtype = float)
    pool_LWGNT = np.zeros((Dim_year,Dim_month,Dim_latitude,Dim_longitude),dtype = float)
    pool_LWTUP = np.zeros((Dim_year,Dim_month,Dim_latitude,Dim_longitude),dtype = float)
    pool_SWGNT = np.zeros((Dim_year,Dim_month,Dim_latitude,Dim_longitude),dtype = float)
    pool_SWTNT = np.zeros((Dim_year,Dim_month,Dim_latitude,Dim_longitude),dtype = float)
    latitude = np.zeros(Dim_latitude,dtype=float)
    longitude = np.zeros(Dim_longitude,dtype=float)
    # loop for calculation
    for i in period:
        for j in index_month:
                # get the key of each variable
            var_key_Rad, var_key_SFlux = var_key_retrieve(datapath_Rad,datapath_SFlux,i,j)
            pool_EFLUX[i-1980,j-1,:,:] = var_key_SFlux.variables['EFLUX'][0,:,:]
            pool_HFLUX[i-1980,j-1,:,:] = var_key_SFlux.variables['HFLUX'][0,:,:]
            latitude = var_key_SFlux.variables['lat'][:]
            longitude = var_key_SFlux.variables['lon'][:]
            pool_LWGNT[i-1980,j-1,:,:] = var_key_Rad.variables['LWGNT'][0,:,:]
            pool_LWTUP[i-1980,j-1,:,:] = var_key_Rad.variables['LWTUP'][0,:,:]
            pool_SWGNT[i-1980,j-1,:,:] = var_key_Rad.variables['SWGNT'][0,:,:]
            pool_SWTNT[i-1980,j-1,:,:] = var_key_Rad.variables['SWTNT'][0,:,:]
    ####################################################################
    ######                 Data Wrapping (NetCDF)                #######
    ####################################################################
    create_netcdf_point(pool_EFLUX,pool_HFLUX,pool_LWGNT,pool_LWTUP,
                        pool_SWGNT, pool_SWTNT, output_path)
    print ('Packing 2D fields of MERRA2 is complete!!!')
    print ('The output is in sleep, safe and sound!!!')
# Out:
# Start retrieving datasets 1980 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1980 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1981 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1982 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1983 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1984 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1985 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1986 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1987 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1988 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1989 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1990 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1991 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1992 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1993 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1994 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1995 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1996 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1997 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1998 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 1999 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2000 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2001 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2002 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2003 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2004 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2005 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2006 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2007 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2008 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2009 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2010 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2011 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2012 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2013 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2014 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2015 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2016 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 01 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 02 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 03 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 04 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 05 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 06 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 07 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 08 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 09 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 10 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 11 (m)
# Retrieving datasets successfully and return the variable key!
# Start retrieving datasets 2017 (y) - 12 (m)
# Retrieving datasets successfully and return the variable key!
# *******************************************************************
# *********************** create netcdf file*************************
# *******************************************************************
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-cfc183706763> in <module>()
#      46     ####################################################################
#      47     create_netcdf_point(pool_EFLUX,pool_HFLUX,pool_LWGNT,pool_LWTUP,
# ---> 48                         pool_SWGNT, pool_SWTNT, output_path)
#      49     print ('Packing 2D fields of MERRA2 is complete!!!')
#      50     print ('The output is in sleep, safe and sound!!!')
#
# <ipython-input-9-7478e21da51d> in create_netcdf_point(pool_EFLUX, pool_HFLUX, pool_LWGNT, pool_LWTUP, pool_SWGNT, pool_SWTNT, output_path)
#       6     # wrap the datasets into netcdf file
#       7     # 'NETCDF3_CLASSIC', 'NETCDF3_64BIT', 'NETCDF4_CLASSIC', and 'NETCDF4'
# ----> 8     data_wrap = Dataset(os.path.koin(output_path, 'surface_merra_monthly_regress_1980_2017_SFlux_Rad.nc'),'w',format = 'NETCDF4')
#       9     # create dimensions for netcdf data
#      10     year_wrap_dim = data_wrap.createDimension('year',Dim_year)
#
# AttributeError: module 'posixpath' has no attribute 'koin'
